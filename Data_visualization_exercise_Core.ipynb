# %% [markdown]
# <a href="https://colab.research.google.com/github/rajasreekalli/Data-Visualization/blob/main/Data_visualization_exercise_Core.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
filename = '/content/drive/MyDrive/RailsToTrails_National Count Data_week.xlsx'
df = pd.read_excel('/content/drive/MyDrive/RailsToTrails_National Count Data_week.xlsx')
df
# Out:
#     Year Timeframe  ... Pedestrians (14 counters)  Bikes (14 counters)
# 0   2019    Week 1  ...                   68957.0              63100.0
# 1   2019    Week 2  ...                   34778.0              31703.0
# 2   2019    Week 3  ...                   32065.0              18082.0
# 3   2019    Week 4  ...                   35016.0              26280.0
# 4   2019    Week 5  ...                   33627.0              24447.0
# ..   ...       ...  ...                       ...                  ...
# 95  2020   Week 46  ...                   96682.0              46105.0
# 96  2020   Week 47  ...                       NaN                  NaN
# 97  2020   Week 48  ...                       NaN                  NaN
# 98  2020   Week 49  ...                       NaN                  NaN
# 99  2020   Week 50  ...                       NaN                  NaN
#
# [100 rows x 7 columns]

# %%
df.hist();

# %%
year_df = df['Year']==2020
print(year_df)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: Year, Length: 100, dtype: bool

# %%
plt.plot(df['Year'], df['Bikes (14 counters)'], c= 'k');
plt.xticks(rotation = 45)
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Bikes (14 counters)', fontsize = 15);
plt.ticklabel_format(useOffset=False, style='plain')
plt.title('bikes based on the year', fontsize = 15);

# %%
plt.plot(df['Year'], df['Counts (31 counters)'], c= 'k');
plt.xticks(rotation = 45)
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Counts (31 counters)', fontsize = 15);
plt.ticklabel_format(useOffset=False, style='plain')
plt.title('bikecounters based on year', fontsize = 15);

# %% [markdown]
# In this graph i choose the year based on 31 counters

# %%
df['Year'].hist();
df['Pedestrians (14 counters)'].hist();
plt.xticks(rotation = 45)
plt.ticklabel_format(useOffset=False, style='plain')
plt.title('Pedestrians based on year', fontsize = 15);
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Pedestrians (14 counters)', fontsize = 15);

# %% [markdown]
# In this graph i choose the pedestrians and year.

# %%
sns.boxplot(x='Year', y='Bikes (14 counters)',data=df,notch=True);

# %%
df.corr()
# Out:
#                                Year  ...  Bikes (14 counters)
# Year                       1.000000  ...             0.461624
# Counts (31 counters)       0.465701  ...             0.823644
# Pedestrians (14 counters)  0.347777  ...             0.660720
# Bikes (14 counters)        0.461624  ...             1.000000
#
# [4 rows x 4 columns]

# %%
corr = df.corr()
sns.heatmap(corr, cmap='Greens');
